# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;
- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
    
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Replace this comment with your code
    
print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# Enter two nonnegative integers: 0 0
#
# The generated list L is:
#    []
#
# Here is M:
#    []
#
# Here is N:
#    []
#
# Here is L again:
#    []

# %%
from random import seed, randrange
help(random.seed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-09b5aa721ac5> in <module>()
#       1 from random import seed, randrange
# ----> 2 help(random.seed)
#
# NameError: name 'random' is not defined

# %%
L = [3, 3, 0, 2]

length = 4
M = [0] * length





print(L)
print(M)
# Out:
# [3, 3, 0, 2]
# [0, 3, 2, 3]

# %%
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
3/2
# Out:
# 1.5

# %%
print(int(5/2), int(3/2))
# Out:
# 2 1

# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;
- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Start: Written by Jack

# Calculate M
# calculate the first two values in M[i]
M[0] = L[int(length / 2)]
M[1] = L[int(0)]

# calculate the other values in M[i]
for i in range(2, length):
    if i % 2 == 0:
        M[int(i)] = L[int(length) - (int(i) // 2)]
    else:
        M[int(i)] = L[int(i) // 2]


# End: Written by Jack

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# Enter two nonnegative integers: 0 4
#
# The generated list L is:
#    [3, 3, 0, 2]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-8b07caa63ff8> in <module>()
#      46 # Calculate M
#      47 # calculate the first two values in M[i]
# ---> 48 M[0] = L[int(length / 2)]
#      49 M[1] = L[int(0)]
#      50
#
# IndexError: list assignment index out of range

# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;
- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Start: Written by Jack

# Calculate M
M = [0] * length

# initialize the first two values in M[i]
M[0] = L[int(length / 2)]
M[1] = L[0]

# calculate the other values in M[i]
for i in range(2, length):
    if i % 2 == 0:
        M[int(i)] = L[int(length) - (int(i) // 2)]
    else:
        M[int(i)] = L[int(i) // 2]


# End: Written by Jack

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# Enter two nonnegative integers: 4 1
#
# The generated list L is:
#    [0]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-aebceb933a46> in <module>()
#      49 # initialize the first two values in M[i]
#      50 M[0] = L[int(length / 2)]
# ---> 51 M[1] = L[0]
#      52
#      53 # calculate the other values in M[i]
#
# IndexError: list assignment index out of range

# %%
L = [3, 3, 0, 2]

length = 4
N = [0] * length

N[0] = L[0]



print(L)
print(N)
# Out:
# [3, 3, 0, 2]
# [3, 0, 0, 0]

# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;
- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Start: Written by Jack

# Calculate M[]
M = [0] * length
# initialize the first two values in M[i]
M[0] = L[int(length / 2)]
M[1] = L[int(0)]

# calculate the other values in M[i]
for i in range(2, length):
    if i % 2 == 0:
        M[int(i)] = L[int(length) - (int(i) // 2)]
    else:
        M[int(i)] = L[int(i) // 2]


# End: Written by Jack

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# Enter two nonnegative integers: 2 4
#
# The generated list L is:
#    [0, 0, 0, 2]
#
# Here is M:
#    [0, 0, 2, 0]
#
# Here is N:
#    []
#
# Here is L again:
#    [0, 0, 0, 2]

# %%
L = [3, 3, 0, 2]

length = 4
N = [0] * length

N[0] = L[0]

# %%
L = [1, 4, 4, 1, 2, 4, 3]
length = 7

# Calculate N[]
N = [0] * length
Mark_L = [True] + [False] * (length -1) #mark the used bit in L[j]

# initialize the first value in N[i]
N[0] = L[0]
# calculate the other values in N[i]
for i in range(1, length):
    j = N[int(i - 1)] # N[i] = L[j]
    while Mark_L[j]:
        j += 1
    N[i] = L[j]
    Mark_L[j] = True
        
# End: Written by Jack
    
print(L)
print(N)
# Out:
# [1, 4, 0, 2, 0]
# [1, 4, 0, 0, 2]

# %%
L = [1, 4, 4, 1, 2, 4, 3]
length = 7

# Calculate N[]
N = [0] * length
Mark_L = [True] + [False] * (length -1) #mark the used bit in L[j]

# initialize the first value in N[i]
N[0] = L[0]
# calculate the other values in N[i]
for i in range(1, length):
    print('i=', i)
    j = N[int(i - 1)] # N[i] = L[j]
    print(j)
    Mark_N
# Out:
# i= 1
# 1
# i= 2
# 0
# i= 3
# 0
# i= 4
# 0
# i= 5
# 0
# i= 6
# 0

# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;

- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Start: Written by Jack

# Calculate M[]
M = [0] * length
# initialize the first two values in M[i]
M[0] = L[int(length / 2)]
M[1] = L[int(0)]
# calculate the other values in M[i]
for i in range(2, length):
    if i % 2 == 0:
        M[int(i)] = L[int(length) - (int(i) // 2)]
    else:
        M[int(i)] = L[int(i) // 2]

# Calculate N[]
N = [0] * length
Mark_L = [True] + [False] * (length -1) #mark the used bit in L[j]
# initialize the first value in N[i]
N[0] = L[0]
# calculate the other values in N[i]
for i in range(1, length):
    j = N[int(i - 1)] # N[i] = L[j]
    while Mark_L[j]:
        j += 1
    N[i] = L[j]
    Mark_L[j] = True
    
# End: Written by Jack

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# Enter two nonnegative integers: 2 6
#
# The generated list L is:
#    [0, 0, 0, 2, 1, 5]
#
# Here is M:
#    [2, 0, 5, 0, 1, 0]
#
# Here is N:
#    [0, 0, 0, 2, 1, 5]
#
# Here is L again:
#    [0, 0, 0, 2, 1, 5]

# %%
L = [1, 4, 4, 1, 2, 4, 3]
length = 7

# Calculate N[]
N = [0] * length
Mark_L = [True] + [False] * (length -1) #mark the used bit in L[j] on 

# initialize the first value in N[i]
N[0] = L[0]
# calculate the other values in N[i]
for i in range(1, length):
    j = N[int(i - 1)] # N[i] = L[j]
    if Mark_L[j]: #if L[j] is already used
        for j in range(length):
            if not Mark_L[j]:
                break
    N[i] = L[j]
    Mark_L[j] = True
        
# End: Written by Jack
    
print(L)
print(N)
# Out:
# [1, 4, 4, 1, 2, 4, 3]
# [1, 4, 2, 4, 1, 4, 3]

# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;

- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Start: Written by Jack

# Test code:
# L = []
# length = len(L)
# print('L = ', L)
# print('length = ', length)

# Calculate M[]
M = [0] * length
M[0] = L[int(length / 2)] # initialize the first two values in M[i]
M[1] = L[int(0)]
for i in range(2, length):  # calculate the other values in M[i]
    if i % 2 == 0:
        M[int(i)] = L[int(length) - (int(i) // 2)]
    else:
        M[int(i)] = L[int(i) // 2]

# Calculate N[]
N = [0] * length
Mark_L = [True] + [False] * (length -1)   #mark the used bit in L[j]
N[0] = L[0] # initialize the first value in N[i]
for i in range(1, length): 
    j = N[int(i - 1)]   # N[i] = L[j], calculate j
    if Mark_L[j]:  #if L[j] is already used, find the lest j which is not used
        for j in range(length):
            if not Mark_L[j]:
                break
    N[i] = L[j]  # calculate the other values in N[i]
    Mark_L[j] = True

# End: Written by Jack

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# Enter two nonnegative integers: 4 0
#
# The generated list L is:
#    []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-6967969c62ca> in <module>()
#      53 # Calculate M[]
#      54 M = [0] * length
# ---> 55 M[0] = L[int(length / 2)] # initialize the first two values in M[i]
#      56 M[1] = L[int(0)]
#      57 for i in range(2, length):  # calculate the other values in M[i]
#
# IndexError: list index out of range

# %%
# Test code:
L = []
length = len(L)
print('L = ', L)
print('length = ', length)

# Calculate M[]
if length  0:
    M = [0] * length
    M[0] = L[int(length / 2)] # initialize the first two values in M[i]
    M[1] = L[int(0)]
    for i in range(2, length):  # calculate the other values in M[i]
        if i % 2 == 0:
            M[int(i)] = L[int(length) - (int(i) // 2)]
        else:
            M[int(i)] = L[int(i) // 2]

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# L =  []
# length =  0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-75f1a2527c9d> in <module>()
#       7 # Calculate M[]
#       8 M = [0] * length
# ----> 9 M[0] = L[int(length / 2)] # initialize the first two values in M[i]
#      10 M[1] = L[int(0)]
#      11 for i in range(2, length):  # calculate the other values in M[i]
#
# IndexError: list index out of range

# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;

- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Start: Written by Jack

# Test code:
# L = []
# length = len(L)
# print('L = ', L)
# print('length = ', length)
if length > 0:
  # Calculate M[]
    M = [0] * length
    M[0] = L[int(length / 2)] # initialize the first two values in M[i]
    M[1] = L[int(0)]
    for i in range(2, length):  # calculate the other values in M[i]
        if i % 2 == 0:
            M[int(i)] = L[int(length) - (int(i) // 2)]
        else:
            M[int(i)] = L[int(i) // 2]

  # Calculate N[]
  N = [0] * length
  Mark_L = [True] + [False] * (length -1)   #mark the used bit in L[j]
  N[0] = L[0] # initialize the first value in N[i]
  for i in range(1, length): 
      j = N[int(i - 1)]   # N[i] = L[j], calculate j
      if Mark_L[j]:  #if L[j] is already used, find the lest j which is not used
          for j in range(length):
              if not Mark_L[j]:
                  break
      N[i] = L[j]  # calculate the other values in N[i]
      Mark_L[j] = True

# End: Written by Jack

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
#   File "<ipython-input-68-56a840751600>", line 64
#     N = [0] * length
#                     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;

- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Start: Written by Jack

# Test code:
# L = []
# length = len(L)
# print('L = ', L)
# print('length = ', length)
if length > 0:
  # Calculate M[]
    M = [0] * length
    M[0] = L[int(length / 2)] # initialize the first two values in M[i]
    M[1] = L[int(0)]
    for i in range(2, length):  # calculate the other values in M[i]
        if i % 2 == 0:
            M[int(i)] = L[int(length) - (int(i) // 2)]
        else:
            M[int(i)] = L[int(i) // 2]

  # # Calculate N[]
  # N = [0] * length
  # Mark_L = [True] + [False] * (length -1)   #mark the used bit in L[j]
  # N[0] = L[0] # initialize the first value in N[i]
  # for i in range(1, length): 
  #     j = N[int(i - 1)]   # N[i] = L[j], calculate j
  #     if Mark_L[j]:  #if L[j] is already used, find the lest j which is not used
  #         for j in range(length):
  #             if not Mark_L[j]:
  #                 break
  #     N[i] = L[j]  # calculate the other values in N[i]
  #     Mark_L[j] = True

# End: Written by Jack

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# Enter two nonnegative integers: 4 0
#
# The generated list L is:
#    []
#
# Here is M:
#    []
#
# Here is N:
#    []
#
# Here is L again:
#    []

# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;

- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Start: Written by Jack

# Test code:
# L = []
# length = len(L)
# print('L = ', L)
# print('length = ', length)

# Calculate M[]
if length > 0:
  M = [0] * length
  M[0] = L[int(length / 2)] # initialize the first two values in M[i]
  M[1] = L[int(0)]
  for i in range(2, length):  # calculate the other values in M[i]
      if i % 2 == 0:
          M[int(i)] = L[int(length) - (int(i) // 2)]
      else:
          M[int(i)] = L[int(i) // 2]

# Calculate N[]
if length > 0:
  N = [0] * length
  Mark_L = [True] + [False] * (length -1)   #mark the used bit in L[j]
  N[0] = L[0] # initialize the first value in N[i]
  for i in range(1, length): 
    j = N[int(i - 1)]   # N[i] = L[j], calculate j
    if Mark_L[j]:  #if L[j] is already used, find the lest j which is not used
        for j in range(length):
            if not Mark_L[j]:
                break
    N[i] = L[j]  # calculate the other values in N[i]
    Mark_L[j] = True

# End: Written by Jack

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# Enter two nonnegative integers: 4 1
#
# The generated list L is:
#    [0]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-8c344d17b734> in <module>()
#      55   M = [0] * length
#      56   M[0] = L[int(length / 2)] # initialize the first two values in M[i]
# ---> 57   M[1] = L[int(0)]
#      58   for i in range(2, length):  # calculate the other values in M[i]
#      59       if i % 2 == 0:
#
# IndexError: list assignment index out of range

# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;

- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Start: Written by Jack

# Test code:
# L = []
# length = len(L)
# print('L = ', L)
# print('length = ', length)

# Calculate M[]


# End: Written by Jack

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# Enter two nonnegative integers: 1 1
#
# The generated list L is:
#    [0]
#
# Here is M:
#    []
#
# Here is N:
#    []
#
# Here is L again:
#    [0]

# %%
from random import seed, randrange
help(random.randrange)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-ae132c605ed5> in <module>()
#       1 from random import seed, randrange
# ----> 2 help(random.randrange)
#
# NameError: name 'random' is not defined

# %%
# Written by *** and Eric Martin for COMP9021


'''
Generates a list L of random nonnegative integers smaller than the length of L,
whose value is input by the user, and outputs two lists:
- a list M consisting of L's middle element, followed by L's first element,
  followed by L's last element, followed by L's second element, followed by
  L's penultimate element...;

- a list N consisting of L[0], possibly followed by L[L[0]], possibly followed by
  L[L[L[0]]]..., for as long as L[L[0]], L[L[L[0]]]... are unused, and then,
  for the least i such that L[i] is unused, followed by L[i], possibly followed by
  L[L[i]], possibly followed by L[L[L[i]]]..., for as long as L[L[i]], L[L[L[i]]]...
  are unused, and then, for the least j such that L[j] is unused, followed by L[j],
  possibly followed by L[L[j]], possibly followed by L[L[L[j]]]..., for as long as
  L[L[j]], L[L[L[j]]]... are unused... until all members of L have been used up.
'''


import sys
from random import seed, randrange


try:
    arg_for_seed, length = input('Enter two nonnegative integers: ').split()
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()
try:
    arg_for_seed, length = int(arg_for_seed), int(length)
    if arg_for_seed < 0 or length < 0:
        raise ValueError
except ValueError:
    print('Incorrect input, giving up.')
    sys.exit()

seed(arg_for_seed)
L = [randrange(length) for _ in range(length)]
print('\nThe generated list L is:')
print('  ', L)
M = []
N = []

# Start: Written by Jack

# Test code:
# L = []
# length = len(L)
# print('L = ', L)
# print('length = ', length)

# Calculate M[]
if length > 0:
  M = [0] * length
  M[0] = L[int(length / 2)] # initialize the first two values in M[i]
  if length > 1:
    M[1] = L[int(0)]
    for i in range(2, length):  # calculate the other values in M[i]
        if i % 2 == 0:
            M[int(i)] = L[int(length) - (int(i) // 2)]
        else:
            M[int(i)] = L[int(i) // 2]

# Calculate N[]
if length > 0:
  N = [0] * length
  Mark_L = [True] + [False] * (length -1)   #mark the used bit in L[j]
  N[0] = L[0] # initialize the first value in N[i]
  for i in range(1, length): 
    j = N[int(i - 1)]   # N[i] = L[j], calculate j
    if Mark_L[j]:  #if L[j] is already used, find the lest j which is not used
        for j in range(length):
            if not Mark_L[j]:
                break
    N[i] = L[j]  # calculate the other values in N[i]
    Mark_L[j] = True

# End: Written by Jack

print('\nHere is M:')
print('  ', M)
print('\nHere is N:')
print('  ', N)
print('\nHere is L again:')
print('  ', L)
# Out:
# Enter two nonnegative integers: 1 1
#
# The generated list L is:
#    [0]
#
# Here is M:
#    [0]
#
# Here is N:
#    [0]
#
# Here is L again:
#    [0]
